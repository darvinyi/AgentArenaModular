# %% [markdown]
# # End-to-end run of Agent Arena v0
#
# This jupyter notebook will take you through all the components of Agent Arena.
#
# ![Main Stages of Agent Arena](media/AgentArenaPartsv2.png)
#
# Each necessary component will be showcased in its v0 form.

# %% [markdown]
# # Building the Agent Arena Dataset
#
# The first aspect of Agent Arena we will have to accomplish is building the dataset.  This will include pulling the right data from Upwork's databases and separating them out for the arena.
#
# There are many important points to take into consideration for Agent Arena Dataset.  After each consideration, we will list possible directions we take and bold the path we took for this demo:
# - How will we store the dataset?
#   - **a job data .csv that contains filepaths to a bucket of attached files**
#   - Advanced Database
# - How will we sample the data from Upwork's database?
#   - **random uniform sample**
#   - sample based on time
#   - sample based on sector/category (like ontological category)
#   - sample based difficulty of task
#   - sample based on skillset needed
#   - sample based on budget
# - Will we include attachment data?
#   - **No.**
#   - Yes.
# - How do we filter for feasibility of the job?
#   - We don't.
#   - **We use an off-the-shelf LLM**
#   - We train Uma to filter for feasibility.
#   - We single-verify with a freelancer.
#   - We triple-verify with a freelancer.
# - Do we include deliverables data?
#   - **No.**
#   - Yes

# %%
# Part 1: Pulling the Data from Upwork Databases

# Using SQL queries, we can pull 1000 random recently posted jobs.
# This will be stored in a .csv file that we save in data/df_randomized.csv.
# Let's take a look at what this looks like.

import pandas as pd

csv_orig = "data/df_randomized_attachment_2.csv"

df = pd.read_csv(csv_orig)
df.head()
# Out:
#    POST_KEY                                              TITLE  \
# 0  63118560                           Book PR/Publicity Expert
# 1  63109904  Lead Generation Specialist Needed for Growing ...
# 2  63097287  2D Pixel Art Assets & Animations Required for ...
# 3  63121476          Country Singer Seeks Social Media Manager
# 4  63098492  Unreal Engine 5 - Optimization of Network Code...
#
#                                          DESCRIPTION  \
# 0  Looking for a PR/publicity expert to help prom...
# 1  Description: We are a dynamic and expanding co...
# 2  I need 3 original pixel art character assets (...
# 3  Are you a social media maven? We're on the loo...
# 4  I am seeking an expert Unreal Engine 5 develop...
#
#                        SECTOR     EXPERIENCE_LEVEL  CLIENT_RATING  \
# 0           Sales & Marketing     Expert/Expensive            NaN
# 1           Sales & Marketing  Cheap/Inexperienced           10.0
# 2           Design & Creative         Intermediate            3.0
# 3           Design & Creative         Intermediate            NaN
# 4  Web, Mobile & Software Dev     Expert/Expensive            8.0
#
#    PROJECTED_VALUE PROJECTED_VALUE_CATEGORY  IS_HOURLY  HOURLY_LOW  \
# 0      4147.919478                       HV       True         0.0
# 1       832.373607                       MV       True         4.0
# 2       821.119678                       MV       True        15.0
# 3      1665.623793                       HV       True         5.0
# 4       309.645726                       LV      False         NaN
#
#    HOURLY_HIGH  BUDGET               COUNTRY             LANGUAGE  \
# 0          0.0     NaN         United States  Native or Bilingual
# 1         10.0     NaN  United Arab Emirates                  NaN
# 2         30.0     NaN               Ireland                  NaN
# 3          7.0     NaN         United States                  NaN
# 4          NaN   200.0         United States                  NaN
#
#                                 SKILLS_AND_EXPERTISE   POST_DATE  \
# 0  Media Relations,Press Distribution,Press Relea...  2024-01-02
# 1  Communications,Data Entry,Email Marketing,Lead...  2024-01-02
# 2   2D Animation,Character Design,Game Art,Pixel Art  2024-01-01
# 3  Facebook,Instagram,Instagram Story,Pinterest,S...  2024-01-02
# 4               C++,Online Multiplayer,Unreal Engine  2024-01-01
#
#    AGORA_POST_ID HAS_ATTACHMENT                        SUBSECTOR  \
# 0   1.742265e+18          False   Marketing, PR & Brand Strategy
# 1   1.742118e+18          False  Lead Generation & Telemarketing
# 2   1.741775e+18          False               Art & Illustration
# 3   1.742311e+18          False                  Performing Arts
# 4   1.741815e+18          False        Game Design & Development
#
#              SUBSUBSECTOR
# 0        Public Relations
# 1         Lead Generation
# 2       Cartoons & Comics
# 3                 Singing
# 4  Video Game Development

# %%
# Part 2: Re-inserting the links

# The data has links removed by default.  All url links will be
# replaced by "(link removed)".  We will use a separate link .csv
# to reinsert the links into the job description.

# TODO: CHECK FOR STALE LINKS

import pandas as pd

from utils.links import reinsert_links

csv_orig = "data/df_randomized_attachment_2.csv"
csv_link = "data/df_links_2.csv"

df = reinsert_links(csv_orig, csv_link)
df.head()
# Out:
#    POST_KEY                                              TITLE  \
# 0  63118560                           Book PR/Publicity Expert
# 1  63109904  Lead Generation Specialist Needed for Growing ...
# 2  63097287  2D Pixel Art Assets & Animations Required for ...
# 3  63121476          Country Singer Seeks Social Media Manager
# 4  63098492  Unreal Engine 5 - Optimization of Network Code...
#
#                                          DESCRIPTION  \
# 0  Looking for a PR/publicity expert to help prom...
# 1  Description: We are a dynamic and expanding co...
# 2  I need 3 original pixel art character assets (...
# 3  Are you a social media maven? We're on the loo...
# 4  I am seeking an expert Unreal Engine 5 develop...
#
#                        SECTOR     EXPERIENCE_LEVEL  CLIENT_RATING  \
# 0           Sales & Marketing     Expert/Expensive            NaN
# 1           Sales & Marketing  Cheap/Inexperienced           10.0
# 2           Design & Creative         Intermediate            3.0
# 3           Design & Creative         Intermediate            NaN
# 4  Web, Mobile & Software Dev     Expert/Expensive            8.0
#
#    PROJECTED_VALUE PROJECTED_VALUE_CATEGORY  IS_HOURLY  HOURLY_LOW  \
# 0      4147.919478                       HV       True         0.0
# 1       832.373607                       MV       True         4.0
# 2       821.119678                       MV       True        15.0
# 3      1665.623793                       HV       True         5.0
# 4       309.645726                       LV      False         NaN
#
#    HOURLY_HIGH  BUDGET               COUNTRY             LANGUAGE  \
# 0          0.0     NaN         United States  Native or Bilingual
# 1         10.0     NaN  United Arab Emirates                  NaN
# 2         30.0     NaN               Ireland                  NaN
# 3          7.0     NaN         United States                  NaN
# 4          NaN   200.0         United States                  NaN
#
#                                 SKILLS_AND_EXPERTISE   POST_DATE  \
# 0  Media Relations,Press Distribution,Press Relea...  2024-01-02
# 1  Communications,Data Entry,Email Marketing,Lead...  2024-01-02
# 2   2D Animation,Character Design,Game Art,Pixel Art  2024-01-01
# 3  Facebook,Instagram,Instagram Story,Pinterest,S...  2024-01-02
# 4               C++,Online Multiplayer,Unreal Engine  2024-01-01
#
#    AGORA_POST_ID HAS_ATTACHMENT                        SUBSECTOR  \
# 0   1.742265e+18          False   Marketing, PR & Brand Strategy
# 1   1.742118e+18          False  Lead Generation & Telemarketing
# 2   1.741775e+18          False               Art & Illustration
# 3   1.742311e+18          False                  Performing Arts
# 4   1.741815e+18          False        Game Design & Development
#
#              SUBSUBSECTOR
# 0        Public Relations
# 1         Lead Generation
# 2       Cartoons & Comics
# 3                 Singing
# 4  Video Game Development

# %%
# Part 3: Downloading attachments

# Some jobs has attachments, as can be seen by the HAS_ATTACHMENT.
# We will go through and download all attachments using the AGORA_POST_ID.

# TODO: CLEAN UP THE FILENAMES.

import pandas as pd

from utils.download_attachments import download_all_attachments

csv_file = "data/df_randomized_attachment_2_links.csv"
save_path = "data"

download_all_attachments(csv_file, save_path)
# Out:
# Found 40 posts with attachments
# 1.7422632388541645e+18
#
# Processing post 1.7422632388541645e+18
# 1.7418171670294897e+18
#
# Processing post 1.7418171670294897e+18
# 1.7421496848639427e+18
#
# Processing post 1.7421496848639427e+18
# 1.7420884549528945e+18
#
# Processing post 1.7420884549528945e+18
# 1.7418426023652106e+18
#
# Processing post 1.7418426023652106e+18
# 1.7417649234269757e+18
#
# Processing post 1.7417649234269757e+18
# 1.742110344372859e+18
#
# Processing post 1.742110344372859e+18
# 1.7416387248557302e+18
#
# Processing post 1.7416387248557302e+18
# 1.7419199680520724e+18
#
# Processing post 1.7419199680520724e+18
# 1.742329012922921e+18
#
# Processing post 1.742329012922921e+18
# 1.7422181666720522e+18
#
# Processing post 1.7422181666720522e+18
# 1.7420300331023524e+18
#
# Processing post 1.7420300331023524e+18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 15
#      12 csv_file = "data/df_randomized_attachment_2_links.csv"
#      13 save_path = "data"
# ---> 15 download_all_attachments(csv_file, save_path)
#
# File ~/Projects/AgentArenaModular/utils/download_attachments.py:92, in download_all_attachments(csv_path, root_dir)
#      90 print(f"\nProcessing post {uid}")
#      91 try:
# ---> 92     download_attachments(uid, root_dir)
#      93 except Exception as e:
#      94     print(f"Error processing post {uid}: {e}")
#
# File ~/Projects/AgentArenaModular/utils/download_attachments.py:25, in download_attachments(uid, root_dir)
#      22 url_first = f"https://swagger.prod.platform.usw2.upwork/proxy/openingsV2DS/openings/{uid}/opening-attachments"
#      23 cmd_first = f"curl -s -H 'Accept: application/json' {url_first} | jq .attachments[].uid"
# ---> 25 stream = os.popen(cmd_first)
#      26 UUIDs = stream.read()
#      27 UUIDs = UUIDs.split("\n")
#
# File <frozen os>:1022, in popen(cmd, mode, buffering)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:1028, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1024         if self.text_mode:
#    1025             self.stderr = io.TextIOWrapper(self.stderr,
#    1026                     encoding=encoding, errors=errors)
# -> 1028     self._execute_child(args, executable, preexec_fn, close_fds,
#    1029                         pass_fds, cwd, env,
#    1030                         startupinfo, creationflags, shell,
#    1031                         p2cread, p2cwrite,
#    1032                         c2pread, c2pwrite,
#    1033                         errread, errwrite,
#    1034                         restore_signals,
#    1035                         gid, gids, uid, umask,
#    1036                         start_new_session, process_group)
#    1037 except:
#    1038     # Cleanup if the child failed starting.
#    1039     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /opt/homebrew/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:1916, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1914 errpipe_data = bytearray()
#    1915 while True:
# -> 1916     part = os.read(errpipe_read, 50000)
#    1917     errpipe_data += part
#    1918     if not part or len(errpipe_data) > 50000:
#
# KeyboardInterrupt:

# %%
# Part 4: Filtering for Feasibility

# Here we use an off-the-shelf LLM to judge whether the job is feasible or not.
# This step can be done by humans as well, such as freelancers.
# Judging feasibility by human experts could be necessary to earn trust in the Arena by our 3rd party partners.
# In the future, this can also be done by Uma if it is trained to understand job feasibility.

from utils.create_feasible_dataset import filter_csv_for_feasible_jobs

csv_feasible = "data/df_randomized_feasible.csv"

filter_csv_for_feasible_jobs(csv_orig, csv_feasible) #This can be manually done with Freelancers.
# Out:
# Reading CSV file...
# Analyzing job descriptions...
# 100%|██████████████████████████████████████████████████████████| 1000/1000 [11:38<00:00,  1.43it/s]
# Saving results...
# Done! Found 187 feasible jobs out of 1000 total jobs analyzed.
# Results saved to: data/df_randomized_feasible.csv

# %%
# Part 5: Cleanup

# We will clean up the data columns and only include what is necessary for the Arena.
# As an example of clean up, we replace post_key with a new Arena JobID.

# TODO: there still seems to be some mapping issues

from utils.clean_up_csv import clean_csv, rename_data_dirs

csv_orig = "data/df_randomized_attachment_links.csv"
data_dir = "data"

# Clean up the .csv file.
clean_csv(csv_orig)
# Rename the attachment directories.
rename_data_dirs(csv_orig, data_dir)
# Out:
# Successfully saved cleaned data to data/df_randomized_attachment_links_cleaned.csv
# Columns saved in order: ID, POST_KEY, AGORA_POST_ID, TITLE, DESCRIPTION, SECTOR, SUBSECTOR, SUBSUBSECTOR, SKILLS_AND_EXPERTISE, EXPERIENCE_LEVEL, CLIENT_RATING, IS_HOURLY, HOURLY_LOW, HOURLY_HIGH, BUDGET, COUNTRY, LANGUAGE, POST_DATE
# Renamed: 1741883886514262016 -> 63101171
# Renamed: 1742203609755996160 -> 63114316
# Renamed: 1741854292737830912 -> 63099905
# Renamed: 1742142968768155648 -> 63111055
# Renamed: 1742258392386719744 -> 63118102
# Renamed: 1742233439487676416 -> 63116411
# Renamed: 1742092662980657152 -> 63108892
# Renamed: 1741882011580149760 -> 63101102
# Renamed: 1742213737218592768 -> 63115009
# Renamed: 1742311730898817024 -> 63121503
# Skipped: 1886807791342739171 (no mapping found)
# Renamed: 1742211586835566592 -> 63114861
# Renamed: 1742170049703628800 -> 63112363
# Renamed: 1742208045882155008 -> 63114628
# Renamed: 1741897769277554688 -> 63101743
# Renamed: 1742280608905674752 -> 63119587
# Renamed: 1741721204732399616 -> 63095822
# Renamed: 1741639827823259648 -> 63093849
# Renamed: 1742207404405145600 -> 63114567
# Renamed: 1742278113219235840 -> 63119427
# Renamed: 1741963184306171904 -> 63104216
# Renamed: 1741956096478203904 -> 63104008
# Renamed: 1741742135334744064 -> 63096360
# Renamed: 1741808081435668480 -> 63098265
# Renamed: 1742272351495442432 -> 63119034
# Renamed: 1741778631783710720 -> 63097390
# Renamed: 1742229586183331840 -> 63116146
# Renamed: 1741990855169941504 -> 63105092
# Renamed: 1741794941918650368 -> 63097872
# Renamed: 1742110344372858880 -> 63109580
# Renamed: 1741683756321148928 -> 63094756
# Renamed: 1742053926791303168 -> 63107468
# Renamed: 1741954121308614656 -> 63103930
# Renamed: 1741917794261848064 -> 63102563
# Renamed: 1741944386618970112 -> 63103586
# Renamed: 1742297284011499520 -> 63120647
# Renamed: 1742278582518333440 -> 63119441
# Renamed: 1741747904226603008 -> 63096530
# Renamed: 1742161112098328576 -> 63111930
# Renamed: 1742296320789585920 -> 63120586
# Renamed: 1741931278139174912 -> 63103077
# Renamed: 1742271104684937216 -> 63118955
#
# Summary:
# Successfully renamed: 41
# Skipped: 1
# Errors: 0

# %%
# Let's take a look at what our final Arena Dataset looks like.

df = pd.read_csv(csv_data)
df.head()
# Out:
#    ID                                              TITLE  \
# 0   0                     Kayak Bass Fishing Logo Design
# 1   1                          C# Native AOT console app
# 2   2                                     Italian typist
# 3   3  Fix Laravel API for Firebase Social & Apple Login
# 4   4     Improve speed loading time and Core Web Vitals
#
#                                          DESCRIPTION  \
# 0  My website is focused on kayak bass fishing, s...
# 1  I need someone to  get a c# native AOT console...
# 2  Hello - I am looking for someone to retype on ...
# 3  Need help with fixing bugs in Laravel based Re...
# 4  Hello,\nWe are looking for someone who is skil...
#
#                        SECTOR  \
# 0           Design & Creative
# 1  Web, Mobile & Software Dev
# 2               Admin Support
# 3  Web, Mobile & Software Dev
# 4  Web, Mobile & Software Dev
#
#                                 SKILLS_AND_EXPERTISE     EXPERIENCE_LEVEL  \
# 0  Abstract Logo,Brand Identity,Emblem Logo,Graph...         Intermediate
# 1                                                 C#         Intermediate
# 2                                 Data Entry,Italian  Cheap/Inexperienced
# 3  API,API Development,API Integration,Firebase,L...         Intermediate
# 4  CSS,JavaScript,Page Speed Optimization,PHP,Web...     Expert/Expensive
#
#    CLIENT_RATING  IS_HOURLY  HOURLY_LOW  HOURLY_HIGH  BUDGET        COUNTRY  \
# 0            9.0       True         0.0          0.0     NaN  United States
# 1            NaN       True        16.0         35.0     NaN  United States
# 2            NaN       True         5.0          7.0     NaN  United States
# 3            NaN      False         NaN          NaN    50.0          India
# 4            0.0      False         NaN          NaN   200.0  United States
#
#   LANGUAGE   POST_DATE
# 0      NaN  2024-01-02
# 1      NaN  2024-01-01
# 2      NaN  2024-01-01
# 3      NaN  2024-01-02
# 4      NaN  2024-01-02

# %% [markdown]
# # Agent Arena API
#
# We can provide an API for agents to use to pull this data.  In this demo, we use a python object that's been initialized with the Arena Dataset we created above.  In the future, this should be a served API that also comes with logging to understand how agents are interacting with the Arena.
#
# In this demo, there are four main API calls:
# - get_num_jobs: returns the total number of jobs in the arena
# - get_jobs_metadata: returns a dictionary of jobID keys mapped to key metadata of the jobs
# - get_job_description: given a jobID, returns the full job description and any additional context.
# - submit_job: submits the deliverables of a job (aka output of the agent) to be evaluated
#
# This would allow agent behavior like looking over all the jobs with `get_jobs_metadata`, and then pick jobs that it thinks it can do, and then it will get the details of that job through `get_job_description`.
#
# One of the most important aspects of the API keeps the Upwork platform in the loop of the agents competing in the arena.  It also lets us keep track of when the API is being triggered and thus, what jobs the agents are currently looking at.

# %%
# Let's take a look at this API

from api.data import AgentArenaData

csv_data = "data/df_randomized_feasible_cleaned.csv"

# Initialize the data
data = AgentArenaData(csv_data)

# Print total number of jobs
print(f"\nTotal number of jobs: {data.get_num_jobs():,}")

# Print metadata for first 3 jobs
print("\nMetadata for first 3 jobs:")
metadata = data.get_jobs_metadata()
for job_id in range(3):
    title, sector, skills, exp_level, budget, country = metadata[job_id]
    print(f"\nJob ID: {job_id}")
    print(f"Title: {title}")
    print(f"Sector: {sector}")
    print(f"Skills: {skills}")
    print(f"Experience Level: {exp_level}")
    print(f"Budget: ${budget:,.2f}" if pd.notna(budget) else "Budget: Not specified")
    print(f"Country: {country}")

# Print description for first job
print("\nDescription for first job:")
print("-" * 80)
print(data.get_job_description(0))
print("-" * 80)
# Out:
# Total number of jobs: 187
#
# Metadata for first 3 jobs:
#
# Job ID: 0
# Title: Kayak Bass Fishing Logo Design
# Sector: Design & Creative
# Skills: Abstract Logo,Brand Identity,Emblem Logo,Graphic Design,Logo Animation,Logo Design,Logo Transparency,Logo Usage Guidelines,Logotype,Minimalist
# Experience Level: Intermediate
# Budget: Not specified
# Country: United States
#
# Job ID: 1
# Title: C# Native AOT console app
# Sector: Web, Mobile & Software Dev
# Skills: C#
# Experience Level: Intermediate
# Budget: Not specified
# Country: United States
#
# Job ID: 2
# Title: Italian typist
# Sector: Admin Support
# Skills: Data Entry,Italian
# Experience Level: Cheap/Inexperienced
# Budget: Not specified
# Country: United States
#
# Description for first job:
# --------------------------------------------------------------------------------
# My website is focused on kayak bass fishing, so I was hoping that you could create a simple modern logo of either a kayak or largemouth bass. Please let me know if you would be able to do this. I've attached a slideshow with a few logo examples that I like. Thank you!
# --------------------------------------------------------------------------------

# %% [markdown]
# # Simple Agent
#
# We create a simple agent.  This agent is just an OpenAI LLM API calls wrapped in a python class.
#
# It is initialized with an API key and the API data class.
#
# The agent will then look through all of the jobs using the `.get_jobs_metadata` module.  Normally, an agent would make a decision on whether or not to take the job.  In our case, we will use a random number generator to coin flip whether our agent takes on this job or not.
#
# If the agent takes on the job, it will feed the job description through gpt-4o api call with a system prompt about how it should attempt to do that job.
#
# Finally, it will submit that job with `submit_job`.

# %%
# Part 1: Initializing the Agent with Acess to the API

from dotenv import load_dotenv
import os
load_dotenv()  # take environment variables

from agent.basic_llm import BasicLLMAgent
from api.data import AgentArenaData

csv_data = "data/df_randomized_feasible_cleaned.csv"

# Initialize the Agent Arena API
API = AgentArenaData(csv_data)

# Initializing the Agent with the API
agent = BasicLLMAgent(os.getenv("OPENAI_API_KEY"), API)

# %%
# Part 2: Processing all the jobs in the Arena and Submitting any Deliverables

agent.process_jobs("output/")
# Out:
# Agent decided to take job 0: Kayak Bass Fishing Logo Design
# Successfully processed job 0. Output saved to: output/output_simpleLLM_0.txt
# Agent decided to take job 1: C# Native AOT console app
# Successfully processed job 1. Output saved to: output/output_simpleLLM_1.txt
# Agent decided not to take job 2: Italian typist
# Agent decided to take job 3: Fix Laravel API for Firebase Social & Apple Login
# Successfully processed job 3. Output saved to: output/output_simpleLLM_3.txt
# Agent decided not to take job 4: Improve speed loading time and Core Web Vitals
# Agent decided to take job 5: Webflow site build
# Successfully processed job 5. Output saved to: output/output_simpleLLM_5.txt
# Agent decided not to take job 6: Data entry | Download files and compress a file
# Agent decided to take job 7: Configure pppoe client via pppd and site to site layer 2 openvpn all via terminal
# Successfully processed job 7. Output saved to: output/output_simpleLLM_7.txt
# Agent decided to take job 8: Add custom domain in form & webhook settings in self-hosted n8n
# Successfully processed job 8. Output saved to: output/output_simpleLLM_8.txt
# Agent decided not to take job 9: Chrome/Gmail plugin or Extension for File Sharing application
# Agent decided to take job 10: Designing a  wiring part on detected symbols of electrical diagrams.
# Successfully processed job 10. Output saved to: output/output_simpleLLM_10.txt
# Agent decided to take job 11: Create AI generated video
# Successfully processed job 11. Output saved to: output/output_simpleLLM_11.txt
# Agent decided not to take job 12: Telegram Bot to post new token creation alerts and liquidity pool additions on Eth and BNB
# Agent decided not to take job 13: Deploy my Wordpress to Elastic Beanstalk on AWS
# Agent decided to take job 14: ChatGPT Machine Learning AI Prompt Creation
# Successfully processed job 14. Output saved to: output/output_simpleLLM_14.txt
# Agent decided to take job 15: Simple android app share file
# Successfully processed job 15. Output saved to: output/output_simpleLLM_15.txt
# Agent decided not to take job 16: looking for a logo for my youtube channel and I want a short intro video for the channel
# Agent decided not to take job 17: Develop shopify app
# Agent decided to take job 18: Python Flask app for appointments
# Successfully processed job 18. Output saved to: output/output_simpleLLM_18.txt
# Agent decided to take job 19: Need a designer to update 30 marketing pieces with new logo, colors, and info."
# Successfully processed job 19. Output saved to: output/output_simpleLLM_19.txt
# Agent decided to take job 20: Outreach list for niche research
# Successfully processed job 20. Output saved to: output/output_simpleLLM_20.txt
# Agent decided not to take job 21: Need Editing and Proofreading - 4500 words
# Agent decided to take job 22: Accountant bookkeeper
# Successfully processed job 22. Output saved to: output/output_simpleLLM_22.txt
# Agent decided to take job 23: Edit videos
# Successfully processed job 23. Output saved to: output/output_simpleLLM_23.txt
# Agent decided not to take job 24: Mr.
# Agent decided not to take job 25: Simple web page scrape
# Agent decided not to take job 26: Document clean up
# Agent decided not to take job 27: Need to use Amazon or Keepa API to pull lowest used price into a google sheet based on the ASIN
# Agent decided not to take job 28: Need e-commerce website with multiple account creation, functionality, and payment processing
# Agent decided to take job 29: Excel Workbook
# Successfully processed job 29. Output saved to: output/output_simpleLLM_29.txt
# Agent decided not to take job 30: Transcribe (Simplified Chinese) and Translate to English
# Agent decided to take job 31: Premiere Pro - Aligning Progression Drone Visits
# Successfully processed job 31. Output saved to: output/output_simpleLLM_31.txt
# Agent decided to take job 32: APA Reference Formatting for Self-Help Book
# Successfully processed job 32. Output saved to: output/output_simpleLLM_32.txt
# Agent decided to take job 33: Replace 5 PNG file in PSD mockup
# Successfully processed job 33. Output saved to: output/output_simpleLLM_33.txt
# Agent decided to take job 34: Update the wording in one graphic picture.
# Successfully processed job 34. Output saved to: output/output_simpleLLM_34.txt
# Agent decided to take job 35: Basic Mobile App for Takeaway Restaurant Business
# Successfully processed job 35. Output saved to: output/output_simpleLLM_35.txt
# Agent decided not to take job 36: Facebook and TikTok Video editing
# Agent decided not to take job 37: Embroidery Digitizing
# Agent decided not to take job 38: 3D logo intro video ( 10-15 second )
# Agent decided not to take job 39: Django Developer Needed for Website with PostgreSQL & MinIO Integration
# Agent decided not to take job 40: Build Landing Page and Prototype/Wireframe for Web Portal.
# Agent decided not to take job 41: Video Edit
# Agent decided to take job 42: Research competitors best selling products
# Successfully processed job 42. Output saved to: output/output_simpleLLM_42.txt
# Agent decided not to take job 43: Build responsive landing page on wix
# Agent decided not to take job 44: InDesign Book Layout Specialist
# Agent decided not to take job 45: Unity Web Based Code Retrieval
# Agent decided to take job 46: RTSP and WebRTC bug fix
# Successfully processed job 46. Output saved to: output/output_simpleLLM_46.txt
# Agent decided not to take job 47: Logo Design
# Agent decided not to take job 48: Stripe set up
# Agent decided not to take job 49: Fashion prints needed for upcoming label
# Agent decided to take job 50: One Page Website Development
# Successfully processed job 50. Output saved to: output/output_simpleLLM_50.txt
# Agent decided to take job 51: Animated infographic / Designer needed
# Successfully processed job 51. Output saved to: output/output_simpleLLM_51.txt
# Agent decided to take job 52: Tech pack for boxers/ men’s underwear
# Successfully processed job 52. Output saved to: output/output_simpleLLM_52.txt
# Agent decided not to take job 53: Synfig Studio animation (15s) needed
# Agent decided to take job 54: Need python script to automatically remove silence from audios mp3
# Successfully processed job 54. Output saved to: output/output_simpleLLM_54.txt
# Agent decided to take job 55: Xiao ESP32C AT command programming
# Successfully processed job 55. Output saved to: output/output_simpleLLM_55.txt
# Agent decided not to take job 56: Create 7 self-directed courses on my website
# Agent decided not to take job 57: Custom Template  1 page sitr Creation
# Agent decided not to take job 58: French translation for toy packaging and internal user manual
# Agent decided to take job 59: I need to write documents and casses for VR game development.
# Successfully processed job 59. Output saved to: output/output_simpleLLM_59.txt
# Agent decided to take job 60: Converting a business directory to publish on kdp
# Successfully processed job 60. Output saved to: output/output_simpleLLM_60.txt
# Agent decided not to take job 61: Design inside pages of a TEXTbook/workbook for Amazon KDP
# Agent decided not to take job 62: 3d File for Website Landing Page
# Agent decided to take job 63: Create 3D Rendering Product Photo of a Bag
# Successfully processed job 63. Output saved to: output/output_simpleLLM_63.txt
# Agent decided not to take job 64: Django Blog Website Development
# Agent decided not to take job 65: Sqaurespace website developer
# Agent decided not to take job 66: Website
# Agent decided not to take job 67: Internet researcher Today:  Help me find .pdfs of customer case studies from B2B software companies?
# Agent decided not to take job 68: Mobile app to find people who helps practice languages
# Agent decided to take job 69: Build mini website for google reviews
# Successfully processed job 69. Output saved to: output/output_simpleLLM_69.txt
# Agent decided to take job 70: Need a custom rendering of a mold for soap/lotion
# Successfully processed job 70. Output saved to: output/output_simpleLLM_70.txt
# Agent decided to take job 71: I need someone who is an animator
# Successfully processed job 71. Output saved to: output/output_simpleLLM_71.txt
# Agent decided to take job 72: Logo Design for Info Neom
# Successfully processed job 72. Output saved to: output/output_simpleLLM_72.txt
# Agent decided not to take job 73: Designer for Custom Widget Cards - Crypto/DeFi Focus
#
# Agent decided to take job 74: List Building: Targeted Marketing Contact List Research & Compilation
# Successfully processed job 74. Output saved to: output/output_simpleLLM_74.txt
# Agent decided to take job 75: Google Calendar for Shift Sign Up
# Successfully processed job 75. Output saved to: output/output_simpleLLM_75.txt
# Agent decided not to take job 76: Data Pooling Expert
# Agent decided not to take job 77: List building for local vending machine business
# Agent decided to take job 78: Need a restaurant menu edited
# Successfully processed job 78. Output saved to: output/output_simpleLLM_78.txt
# Agent decided to take job 79: Graphical Abstract Design for MXene-based Meta-Absorber
# Successfully processed job 79. Output saved to: output/output_simpleLLM_79.txt
# Agent decided not to take job 80: Improve Image
# Agent decided to take job 81: Wordpress migration and elementor issues
# Successfully processed job 81. Output saved to: output/output_simpleLLM_81.txt
# Agent decided to take job 82: I need someone to fix up my logo
# Successfully processed job 82. Output saved to: output/output_simpleLLM_82.txt
# Agent decided to take job 83: Modification in dating app
# Successfully processed job 83. Output saved to: output/output_simpleLLM_83.txt
# Agent decided not to take job 84: Wordpress Plugin Developer
# Agent decided to take job 85: One week Job - Code Simple Landing page
# Successfully processed job 85. Output saved to: output/output_simpleLLM_85.txt
# Agent decided to take job 86: Squarespace technical website help
# Successfully processed job 86. Output saved to: output/output_simpleLLM_86.txt
# Agent decided not to take job 87: PCB Board Desgin
# Agent decided to take job 88: Build a responsive  wordpress website
# Successfully processed job 88. Output saved to: output/output_simpleLLM_88.txt
# Agent decided not to take job 89: Create animation for video intro
# Agent decided to take job 90: Pdf form field editor
# Successfully processed job 90. Output saved to: output/output_simpleLLM_90.txt
# Agent decided to take job 91: Ethereum Gas Testing Proof-of-Concept
# Successfully processed job 91. Output saved to: output/output_simpleLLM_91.txt
# Agent decided to take job 92: Amazon images and video
# Successfully processed job 92. Output saved to: output/output_simpleLLM_92.txt
# Agent decided to take job 93: Edit YOUTUBE Thumbnails
# Successfully processed job 93. Output saved to: output/output_simpleLLM_93.txt
# Agent decided to take job 94: Data Entry - Look up home prices on Zillow - FOR ASQA K.
# Successfully processed job 94. Output saved to: output/output_simpleLLM_94.txt
# Agent decided not to take job 95: Architectural Modeling- Residential for Animation
# Agent decided not to take job 96: Need google sheet that updates when new data is added
# Agent decided not to take job 97: Website
# Agent decided not to take job 98: Project NL (31 words) EN - IT | Medical
# Agent decided not to take job 99: General Typing of Documents
# Agent decided to take job 100: Need video - voiceover explainer video
# Successfully processed job 100. Output saved to: output/output_simpleLLM_100.txt
# Agent decided not to take job 101: Smart Contract Deployment
# Agent decided to take job 102: Data Extraction
# Successfully processed job 102. Output saved to: output/output_simpleLLM_102.txt
# Agent decided to take job 103: Typist
# Successfully processed job 103. Output saved to: output/output_simpleLLM_103.txt
# Agent decided to take job 104: List Building
# Successfully processed job 104. Output saved to: output/output_simpleLLM_104.txt
# Agent decided to take job 105: Re-create this poster in hi res print format
# Successfully processed job 105. Output saved to: output/output_simpleLLM_105.txt
# Agent decided not to take job 106: Data Entry for Ecommerce Space
# Agent decided to take job 107: Dokan Modifications
# Successfully processed job 107. Output saved to: output/output_simpleLLM_107.txt
# Agent decided not to take job 108: Populate Excel Using API
# Agent decided not to take job 109: Wordpress Guru Needed
# Agent decided not to take job 110: Data Entry- Provide entry from a restaurant menu into another
# Agent decided not to take job 111:  developer to create a receipt generation system
# Agent decided to take job 112: Make a beautiful graphic design for instant noodle packaging.
# Successfully processed job 112. Output saved to: output/output_simpleLLM_112.txt
# Agent decided not to take job 113: Food products Website
# Agent decided to take job 114: Financial Services organizations
# Successfully processed job 114. Output saved to: output/output_simpleLLM_114.txt
# Agent decided to take job 115: Lead generation
#
# Successfully processed job 115. Output saved to: output/output_simpleLLM_115.txt
# Agent decided to take job 116: Change quantity selection from dropdown to button
# Successfully processed job 116. Output saved to: output/output_simpleLLM_116.txt
# Agent decided not to take job 117: Deep Learning Model Training and Deployment on Nvidia Jetson Devices
# Agent decided not to take job 118: Create a post mailing list
# Agent decided to take job 119: Create Bottle Labels
# Successfully processed job 119. Output saved to: output/output_simpleLLM_119.txt
# Agent decided not to take job 120: Create direct mailing list for property owners
# Agent decided to take job 121: Photoshop a photo, title and image
# Successfully processed job 121. Output saved to: output/output_simpleLLM_121.txt
# Agent decided to take job 122: Bzr site work
# Successfully processed job 122. Output saved to: output/output_simpleLLM_122.txt
# Agent decided not to take job 123: Logo for PALESTINE
# Agent decided not to take job 124: Structural Engineer Needed to Review a Hanging Metal Retail Canopy
# Agent decided to take job 125: Autocad Design Electrical Engineering
# Successfully processed job 125. Output saved to: output/output_simpleLLM_125.txt
# Agent decided to take job 126: Need Wordpress Page Converted to HTML
# Successfully processed job 126. Output saved to: output/output_simpleLLM_126.txt
# Agent decided not to take job 127: HTML + TailwindCSS for 5 page website (fully responsive)
# Agent decided not to take job 128: Design a Logo
# Agent decided to take job 129: Graphic design
# Successfully processed job 129. Output saved to: output/output_simpleLLM_129.txt
# Agent decided not to take job 130: Documents Retyping
# Agent decided to take job 131: Test Project - Ongoing Tableau Dashboard Development Work
# Successfully processed job 131. Output saved to: output/output_simpleLLM_131.txt
# Agent decided to take job 132: Soa school project
# Successfully processed job 132. Output saved to: output/output_simpleLLM_132.txt
# Agent decided not to take job 133: Experienced Python Developer And Web Scraper
# Agent decided to take job 134: I need help with animation and a mascot creation for my brand. Emailemu.com
# Successfully processed job 134. Output saved to: output/output_simpleLLM_134.txt
# Agent decided not to take job 135: SaaS landing page web design
# Agent decided to take job 136: Real Estate Brokerage Website Development
# Successfully processed job 136. Output saved to: output/output_simpleLLM_136.txt
# Agent decided to take job 137: Python combinations / unique combos from lists
# Successfully processed job 137. Output saved to: output/output_simpleLLM_137.txt
# Agent decided to take job 138: Portfolio website backend
# Successfully processed job 138. Output saved to: output/output_simpleLLM_138.txt
# Agent decided not to take job 139: French Speakers for Sentence Recording (Only France Natives)
#
# Agent decided to take job 140: Logo Design
# Successfully processed job 140. Output saved to: output/output_simpleLLM_140.txt
# Agent decided not to take job 141: Grant Writer/Researcher needed for fast turnaround Grant Prospectus
# Agent decided to take job 142: PDF to Excel Formatting
# Successfully processed job 142. Output saved to: output/output_simpleLLM_142.txt
# Agent decided to take job 143: Finish a google sketchup drawing for me
# Successfully processed job 143. Output saved to: output/output_simpleLLM_143.txt
# Agent decided not to take job 144: Chorme extension based on openai vision api
# Agent decided to take job 145: Need a gif created for Happy New Year 2024
# Successfully processed job 145. Output saved to: output/output_simpleLLM_145.txt
# Agent decided to take job 146: Reformat a Children's Book
# Successfully processed job 146. Output saved to: output/output_simpleLLM_146.txt
# Agent decided to take job 147: Add a custom pop-up to Gravity form in WordPress site
# Successfully processed job 147. Output saved to: output/output_simpleLLM_147.txt
# Agent decided to take job 148: Making Llama (LLM) Labeling Model work
# Successfully processed job 148. Output saved to: output/output_simpleLLM_148.txt
# Agent decided to take job 149: Website updates
# Successfully processed job 149. Output saved to: output/output_simpleLLM_149.txt
# Agent decided not to take job 150: Create and Design a Landing page - Real Estate Activities
# Agent decided not to take job 151: Shopify store expert needed
# Agent decided not to take job 152: Fix minor Issues and Burger Menu for Webflow Website
# Agent decided to take job 153: Figma creative person for creating onboarding screen
# Successfully processed job 153. Output saved to: output/output_simpleLLM_153.txt
# Agent decided not to take job 154: Add products, descriptions and upload images for a WordPress web shop
# Agent decided not to take job 155: Exterior Rendering Video - Lumion
# Agent decided not to take job 156: Create List of Positive Impact Conferences Gloibally
# Agent decided to take job 157: UI/UX solution for 3 features of our Mobile App
# Successfully processed job 157. Output saved to: output/output_simpleLLM_157.txt
# Agent decided not to take job 158: UI/UX development for my web design
# Agent decided to take job 159: Graphic Designer Needed to Highlight Exclusive 'Guest Card' Feature in Airbnb Listing
# Successfully processed job 159. Output saved to: output/output_simpleLLM_159.txt
# Agent decided not to take job 160: Godot iOS Plugin
# Agent decided not to take job 161: Video Editor and Animator
# Agent decided to take job 162: Transcription of Interviews to Prevent Diabetes in Latino Families
# Successfully processed job 162. Output saved to: output/output_simpleLLM_162.txt
# Agent decided not to take job 163: Jotform Design
# Agent decided to take job 164: Translation of technical text, English - French
# Successfully processed job 164. Output saved to: output/output_simpleLLM_164.txt
# Agent decided not to take job 165: Laravel Backend Developer - Connecting several  API-Endpoints
# Agent decided not to take job 166: Formatting ebooks
# Agent decided to take job 167: Install Ai Chatbot into Squarespace website
# Successfully processed job 167. Output saved to: output/output_simpleLLM_167.txt
# Agent decided not to take job 168: Figma to Angular - UI/UX Screen Development
# Agent decided to take job 169: 3CX LightSail Upgrade
# Successfully processed job 169. Output saved to: output/output_simpleLLM_169.txt
# Agent decided not to take job 170: Square Space - adding
# Agent decided to take job 171: Flutter chat video audio calls use WebRtc with linux host and Laravel backend
# Successfully processed job 171. Output saved to: output/output_simpleLLM_171.txt
# Agent decided not to take job 172: Website fixing
# Agent decided to take job 173: Develop Market Research of Sustainable Clothing Brands
# Successfully processed job 173. Output saved to: output/output_simpleLLM_173.txt
# Agent decided not to take job 174: Parse 238 websites and get data
# Agent decided not to take job 175: Graphic Designer for Baking Business
# Agent decided to take job 176: Logo for photography business
# Successfully processed job 176. Output saved to: output/output_simpleLLM_176.txt
# Agent decided to take job 177: Create simple Android App to practice multiplication
# Successfully processed job 177. Output saved to: output/output_simpleLLM_177.txt
# Agent decided not to take job 178: English to Romanian Translation
# Agent decided not to take job 179: I want to edit a vlog video for my YouTube channel.
# Agent decided to take job 180: Copy typing
# Successfully processed job 180. Output saved to: output/output_simpleLLM_180.txt
# Agent decided to take job 181: Article Proofreading in French
# Successfully processed job 181. Output saved to: output/output_simpleLLM_181.txt
# Agent decided to take job 182: Saloons Company in USA
# Successfully processed job 182. Output saved to: output/output_simpleLLM_182.txt
# Agent decided not to take job 183: Build a Shopify app that can create ads in a new space
# Agent decided not to take job 184: Integrate TipTap (rich text editor) into an Open Source document data processor based on Tauri
# Agent decided to take job 185: Edit 4-12 GB sized TV episodes for YouTube upload
# Successfully processed job 185. Output saved to: output/output_simpleLLM_185.txt
# Agent decided to take job 186: Translate bookkeeping audit from spanish to english
# Successfully processed job 186. Output saved to: output/output_simpleLLM_186.txt

# %% [markdown]
# # Evaluating Submitted Results
#
# We will now take all of the outputs and verify them.  We do this doing a very simple wrapper around an LLM that takes a look at all the output files and determines whether the output deserved to earn payment or not.  However, this can be done in several other ways:
# - By human verification (using freelancers who are experts in this area)
# - By using a well-trained LLM (i.e. Uma trained on this task)
# - By the client themselves.

# %%
# Part 1: We initialize our evaluator
from dotenv import load_dotenv
import os
load_dotenv()  # take environment variables

from agent.verifier_simple import SimpleVerifier
from api.data import AgentArenaData

csv_data = "data/df_randomized_feasible_cleaned.csv"

# Initialize the Agent Arena API
API = AgentArenaData(csv_data)

# Initializing the evaluator
verifier = SimpleVerifier(os.getenv("OPENAI_API_KEY"), API)

# %%
# Part 2: Evaluating all Outputs

verifier.process_outputs("output/")
# Out:
# Job: RTSP and WebRTC bug fix (ID: 46)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Tech pack for boxers/ men’s underwear  (ID: 52)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Making Llama (LLM) Labeling Model work (ID: 148)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: One week Job - Code Simple Landing page (ID: 85)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Ethereum Gas Testing Proof-of-Concept (ID: 91)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Pdf form field editor (ID: 90)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Website updates (ID: 149)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Animated infographic / Designer needed  (ID: 51)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Create simple Android App to practice multiplication (ID: 177)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Graphical Abstract Design for MXene-based Meta-Absorber (ID: 79)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Amazon images and video (ID: 92)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Squarespace technical website help (ID: 86)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Edit YOUTUBE Thumbnails (ID: 93)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Need a restaurant menu edited (ID: 78)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Logo for photography business (ID: 176)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Transcription of Interviews to Prevent Diabetes in Latino Families (ID: 162)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: One Page Website Development (ID: 50)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Need python script to automatically remove silence from audios mp3 (ID: 54)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Modification in dating app (ID: 83)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: I need someone to fix up my logo (ID: 82)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Develop Market Research of Sustainable Clothing Brands (ID: 173)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Xiao ESP32C AT command programming (ID: 55)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Install Ai Chatbot into Squarespace website  (ID: 167)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Build mini website for google reviews  (ID: 69)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Graphic Designer Needed to Highlight Exclusive 'Guest Card' Feature in Airbnb Listing (ID: 159)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Flutter chat video audio calls use WebRtc with linux host and Laravel backend (ID: 171)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Data Entry - Look up home prices on Zillow - FOR ASQA K. (ID: 94)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Wordpress migration and elementor issues (ID: 81)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Translation of technical text, English - French (ID: 164)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Research competitors best selling products (ID: 42)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Fix Laravel API for Firebase Social & Apple Login (ID: 3)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Typist  (ID: 103)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Premiere Pro - Aligning Progression Drone Visits (ID: 31)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Need a designer to update 30 marketing pieces with new logo, colors, and info." (ID: 19)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Python Flask app for appointments (ID: 18)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Data Extraction  (ID: 102)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Change quantity selection from dropdown to button (ID: 116)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Kayak Bass Fishing Logo Design (ID: 0)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: APA Reference Formatting for Self-Help Book (ID: 32)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Need video - voiceover explainer video (ID: 100)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Financial Services organizations  (ID: 114)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Graphic design (ID: 129)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Lead generation
#  (ID: 115)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Replace 5 PNG file in PSD mockup (ID: 33)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: C# Native AOT console app (ID: 1)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Webflow site build (ID: 5)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Re-create this poster in hi res print format (ID: 105)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Edit videos (ID: 23)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Accountant bookkeeper (ID: 22)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: List Building (ID: 104)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Portfolio website backend (ID: 138)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Make a beautiful graphic design for instant noodle packaging.  (ID: 112)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Outreach list for niche research (ID: 20)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Update the wording in one graphic picture. (ID: 34)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Basic Mobile App for Takeaway Restaurant Business (ID: 35)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Dokan Modifications (ID: 107)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Configure pppoe client via pppd and site to site layer 2 openvpn all via terminal (ID: 7)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Real Estate Brokerage Website Development (ID: 136)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Bzr site work (ID: 122)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Designing a  wiring part on detected symbols of electrical diagrams. (ID: 10)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Create AI generated video  (ID: 11)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Python combinations / unique combos from lists (ID: 137)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Photoshop a photo, title and image (ID: 121)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: I need help with animation and a mascot creation for my brand. Emailemu.com   (ID: 134)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Add custom domain in form & webhook settings in self-hosted n8n (ID: 8)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Test Project - Ongoing Tableau Dashboard Development Work (ID: 131)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Autocad Design Electrical Engineering (ID: 125)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Create Bottle Labels (ID: 119)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Excel Workbook (ID: 29)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Simple android app share file (ID: 15)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: ChatGPT Machine Learning AI Prompt Creation (ID: 14)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Need Wordpress Page Converted to HTML (ID: 126)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Soa school project (ID: 132)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: 3CX LightSail Upgrade (ID: 169)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Saloons Company in USA (ID: 182)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Logo Design for Info Neom (ID: 72)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Logo Design (ID: 140)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: PDF to Excel Formatting (ID: 142)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Need a custom rendering of a mold for soap/lotion (ID: 70)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Article Proofreading in French (ID: 181)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Copy typing (ID: 180)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: I need to write documents and casses for VR game development. (ID: 59)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: UI/UX solution for 3 features of our Mobile App (ID: 157)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Finish a google sketchup drawing for me  (ID: 143)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: I need someone who is an animator (ID: 71)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Google Calendar for Shift Sign Up (ID: 75)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Add a custom pop-up to Gravity form in WordPress site (ID: 147)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Figma creative person for creating onboarding screen  (ID: 153)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Edit 4-12 GB sized TV episodes for YouTube upload (ID: 185)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Converting a business directory to publish on kdp (ID: 60)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: List Building: Targeted Marketing Contact List Research & Compilation (ID: 74)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Reformat a Children's Book (ID: 146)
# Agent: simpleLLM
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Translate bookkeeping audit from spanish to english (ID: 186)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Build a responsive  wordpress website  (ID: 88)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Need a gif created for Happy New Year 2024 (ID: 145)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Create 3D Rendering Product Photo of a Bag (ID: 63)
# Agent: simpleLLM
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Results saved to output/results.csv

# %%
# Let's take a Look at the Results of the Evaluation

import pandas as pd

csv_results = "output/results.csv"

df = pd.read_csv(csv_results)
df.head()
# Out:
#    jobID simpleLLM
# 0      0      fail
# 1      1       win
# 2      3       win
# 3      5      fail
# 4      7      fail

# %% [markdown]
# # Metrics
#
# The final aspect of the arena will be synthesizing all of the results from the different competing agents as well as data collected from the API (such as time to job completion or price of running the agent).  This will allow us to do important analysis on the different models and present different metrics that showcase the strenghts and weaknesses of different agents.
