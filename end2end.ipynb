# %% [markdown]
# # End-to-end run of Agent Arena v1
#
# This jupyter notebook will take you through all the components of Agent Arena.
#
# ![Main Stages of Agent Arena](media/AgentArenaParts.jpg)
#
# This script will showcase all the aspects of Agent Arena, but things are still quite hacky.

# %% [markdown]
# # Building the Agent Arena Dataset
#
# The first aspect of Agent Arena we will have to accomplish is building the dataset.  This will include pulling the right data from Upwork's databases and separating them out for the arena.
#
# There are many important points to take into consideration for Agent Arena Dataset.  After each consideration, we will list possible directions we take and bold the path we took for this demo:
# - How will we store the dataset?
#   - SQL Database
#   - **a job data .csv that contains filepaths to a bucket of attached files**
# - How will we sample the data from Upwork's database?
#   - **random uniform sample**
#   - sample based on time
#   - sample based on sector/category (like ontological category)
#   - sample based difficulty of task
#   - sample based on skillset needed
#   - sample based on budget
# - How do we filter for feasibility of the job?
#   - We don't.
#   - **We use an off-the-shelf LLM with a prompt and a prayer.**
#   - We train Uma to filter for feasibility.
#   - We single-verify with a freelancer.
#   - We triple-verify with a freelancer.
# - Do we include deliverables data?
#   - Yes
#   - **No.**
#
# Also important to note: at the current data (3/25/25), I (darvin) don't have the ability to SQL query snowflake.  Nor do we as a team have the ability to find the attached files of the jobs.  Thus, this will be reflected in the code.
#
# ## The biggest gaps (rank ordered)
# 1. **We do not have attachment data.**
# 2. **We do not have deliverables data.**
# 3. **We need a stronger pipeline of pulling data.**
# 4. **We need to verify feasiblity with human freelancers.**
# 5. **We need to train Uma to learn feasiblity.**

# %%
# Pulling the data: this is all fake/pseudo-code that represents what we do today.
# When this is all done, let's say we end up with 1000 rows of random uniform data in a .csv file in data/.
# We will save this as data/df_randomized.csv

# import snowflake_database
# import ted
# ted.pull_data(snowflake_database, "random_uniform")

import pandas as pd

csv_orig = "data/df_randomized.csv"

df = pd.read_csv(csv_orig)
df.head()
# Out:
#    POST_KEY                                              TITLE  \
# 0  63107529  Need shopify backend expert for selecting my p...
# 1  63114550                            Presentation Pitch Deck
# 2  63120800                        Video creation and editing
# 3  63095881              Real Estate Cold Calling Lead Manager
# 4  63108525   Intercom Ticketing Software Setup and Automation
#
#                                          DESCRIPTION  \
# 0  This is going to be 5 min work for an expert ....
# 1  Hi there\n\nI want to have a series of calls e...
# 2  \nI would like videos that mother is making to...
# 3  We seek a skilled and experienced cold-calling...
# 4  We are seeking an experienced professional to ...
#
#                        SECTOR  EXPERIENCE_LEVEL  CLIENT_RATING  \
# 0  Web, Mobile & Software Dev  Expert/Expensive            NaN
# 1                     Writing  Expert/Expensive            NaN
# 2           Design & Creative      Intermediate            NaN
# 3           Sales & Marketing      Intermediate            NaN
# 4           Sales & Marketing      Intermediate            NaN
#
#    PROJECTED_VALUE PROJECTED_VALUE_CATEGORY  IS_HOURLY  HOURLY_LOW  \
# 0        83.195333                      VLV      False         NaN
# 1       415.515007                       LV      False         NaN
# 2       312.696550                       LV      False         NaN
# 3      1657.371981                       HV       True         6.0
# 4       844.183541                       MV       True        15.0
#
#    HOURLY_HIGH  BUDGET         COUNTRY LANGUAGE  \
# 0          NaN    40.0   United States      NaN
# 1          NaN   300.0  United Kingdom      NaN
# 2          NaN     5.0       Australia      NaN
# 3         10.0     NaN   United States      NaN
# 4         75.0     NaN   United States      NaN
#
#                                 SKILLS_AND_EXPERTISE   POST_DATE
# 0                                            Shopify  2024-01-02
# 1  Business Presentation,Marketing Presentation,M...  2024-01-02
# 2  Adobe After Effects,Adobe Premiere Pro,Cinemat...  2024-01-02
# 3  Cold Calling,Communications,Lead Generation,Sa...  2024-01-01
# 4    API,Chatbot Development,Intercom,Python,Zendesk  2024-01-02

# %%
from utils.create_feasible_dataset import filter_csv_for_feasible_jobs

csv_feasible = "data/df_randomized_feasible.csv"

filter_csv_for_feasible_jobs(csv_orig, csv_feasible) #This can be manually done with Freelancers.
# Out:
# Reading CSV file...
# Analyzing job descriptions...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [11:41<00:00,  1.43it/s]
# Saving results...
# Done! Found 188 feasible jobs out of 1000 total jobs analyzed.
# Results saved to: data/df_randomized_feasible.csv

# %%
from utils.clean_up_csv import clean_csv

csv_data = "data/df_randomized_feasible_cleaned.csv"

clean_csv(csv_feasible, csv_data)
# Out:
# Successfully saved cleaned data to data/df_randomized_feasible_cleaned.csv
# Columns saved in order: ID, TITLE, DESCRIPTION, SECTOR, SKILLS_AND_EXPERTISE, EXPERIENCE_LEVEL, CLIENT_RATING, IS_HOURLY, HOURLY_LOW, HOURLY_HIGH, BUDGET, COUNTRY, LANGUAGE, POST_DATE
# Number of actionable tasks saved: 188

# %%
df = pd.read_csv(csv_data)
df.head()
# Out:
#    ID                                              TITLE  \
# 0   0                     Kayak Bass Fishing Logo Design
# 1   1                          C# Native AOT console app
# 2   2                                     Italian typist
# 3   3  Fix Laravel API for Firebase Social & Apple Login
# 4   4     Improve speed loading time and Core Web Vitals
#
#                                          DESCRIPTION  \
# 0  My website is focused on kayak bass fishing, s...
# 1  I need someone to  get a c# native AOT console...
# 2  Hello - I am looking for someone to retype on ...
# 3  Need help with fixing bugs in Laravel based Re...
# 4  Hello,\nWe are looking for someone who is skil...
#
#                        SECTOR  \
# 0           Design & Creative
# 1  Web, Mobile & Software Dev
# 2               Admin Support
# 3  Web, Mobile & Software Dev
# 4  Web, Mobile & Software Dev
#
#                                 SKILLS_AND_EXPERTISE     EXPERIENCE_LEVEL  \
# 0  Abstract Logo,Brand Identity,Emblem Logo,Graph...         Intermediate
# 1                                                 C#         Intermediate
# 2                                 Data Entry,Italian  Cheap/Inexperienced
# 3  API,API Development,API Integration,Firebase,L...         Intermediate
# 4  CSS,JavaScript,Page Speed Optimization,PHP,Web...     Expert/Expensive
#
#    CLIENT_RATING  IS_HOURLY  HOURLY_LOW  HOURLY_HIGH  BUDGET        COUNTRY  \
# 0            9.0       True         0.0          0.0     NaN  United States
# 1            NaN       True        16.0         35.0     NaN  United States
# 2            NaN       True         5.0          7.0     NaN  United States
# 3            NaN      False         NaN          NaN    50.0          India
# 4            0.0      False         NaN          NaN   200.0  United States
#
#   LANGUAGE   POST_DATE
# 0      NaN  2024-01-02
# 1      NaN  2024-01-01
# 2      NaN  2024-01-01
# 3      NaN  2024-01-02
# 4      NaN  2024-01-02

# %% [markdown]
# # Lightweight API
#
# We can provide a lightweight API for agents to use to pull this data.  In this ipython notebook demo, a VERY lightweight AgentArenaData object is acting as a stand in for an API that we will serve one day.
#
# In this demo, there are three main API calls:
# - get_num_jobs: returns the total number of jobs in the arena
# - get_jobs_metadata: returns a dictionary of jobID keys mapped to key metadata of the jobs
# - get_job_description: given a jobID, returns the full job description and attachments (**NOTE: WE DON'T HAVE ATTACHMENTS YET SO THIS IS NOT BUILT.**)
# - submit_job: this is a very simple function to help save the output string as a .txt file.  For the real API, we probably want to design something stronger with output directories to handle any complexity of files being the output of the agent's work.
#
# The assumed agent behavior loop is that it will look over all the jobs with `get_jobs_metadata`, and then pick jobs that it thinks it can do, and then it will get the details of that job through `get_job_description`.
#
# It is important to note that that this is not more secure than just passing the full .csv.  However, it keeps the Upwork platform in the loop of the agents competing in the arena.  It also lets us keep track of when the API is being triggered and thus, what jobs the agents are currently looking at.
#
# ## The biggest gaps (rank ordered)
# 1. **We need to create a real API that's served.**
# 2. **We need to creating logging associated with API Calls.**
# 3. **We need to design an actually good API.**

# %%
from api.data import AgentArenaData

csv_data = "data/df_randomized_feasible_cleaned.csv"

# Initialize the data
data = AgentArenaData(csv_data)

# Print total number of jobs
print(f"\nTotal number of jobs: {data.get_num_jobs():,}")

# Print metadata for first 3 jobs
print("\nMetadata for first 3 jobs:")
metadata = data.get_jobs_metadata()
for job_id in range(3):
    title, sector, skills, exp_level, budget, country = metadata[job_id]
    print(f"\nJob ID: {job_id}")
    print(f"Title: {title}")
    print(f"Sector: {sector}")
    print(f"Skills: {skills}")
    print(f"Experience Level: {exp_level}")
    print(f"Budget: ${budget:,.2f}" if pd.notna(budget) else "Budget: Not specified")
    print(f"Country: {country}")

# Print description for first job
print("\nDescription for first job:")
print("-" * 80)
print(data.get_job_description(0))
print("-" * 80)
# Out:
# Total number of jobs: 188
#
# Metadata for first 3 jobs:
#
# Job ID: 0
# Title: Kayak Bass Fishing Logo Design
# Sector: Design & Creative
# Skills: Abstract Logo,Brand Identity,Emblem Logo,Graphic Design,Logo Animation,Logo Design,Logo Transparency,Logo Usage Guidelines,Logotype,Minimalist
# Experience Level: Intermediate
# Budget: Not specified
# Country: United States
#
# Job ID: 1
# Title: C# Native AOT console app
# Sector: Web, Mobile & Software Dev
# Skills: C#
# Experience Level: Intermediate
# Budget: Not specified
# Country: United States
#
# Job ID: 2
# Title: Italian typist
# Sector: Admin Support
# Skills: Data Entry,Italian
# Experience Level: Cheap/Inexperienced
# Budget: Not specified
# Country: United States
#
# Description for first job:
# --------------------------------------------------------------------------------
# My website is focused on kayak bass fishing, so I was hoping that you could create a simple modern logo of either a kayak or largemouth bass. Please let me know if you would be able to do this. I've attached a slideshow with a few logo examples that I like. Thank you!
# --------------------------------------------------------------------------------

# %% [markdown]
# # Simple Agent
#
# We create the world's worst agent.  This agent is just an OpenAI LLM API calls wrapped in a python class.
#
# It is initialized with an API key and the API data class.
#
# The "agent" will then look through all of the jobs using the `.get_jobs_metadata` module.  Normally, an agent would make a decision on whether or not to take the job.  In our case, we will simply use a random number generator to coin flip whether our agent takes on this job or not.
#
# If the agent takes on the job, it will simply feed the job description through gpt-4o api call with a system prompt about how it should attempt to do that job.
#
# Finally, it will submit that job with `submit_job`.

# %%
from dotenv import load_dotenv
import os
load_dotenv()  # take environment variables

from agent.basic_llm import BasicLLMAgent
from api.data import AgentArenaData

csv_data = "data/df_randomized_feasible_cleaned.csv"

# Initialize the data
data = AgentArenaData(csv_data)

agent = BasicLLMAgent(os.getenv("OPENAI_API_KEY"), data)
agent.process_jobs("output/")
# Out:
# Agent decided not to take job 0: Kayak Bass Fishing Logo Design
# Agent decided not to take job 1: C# Native AOT console app
# Agent decided to take job 2: Italian typist
# Successfully processed job 2. Output saved to: output/output_gpt-4_2.txt
# Agent decided to take job 3: Fix Laravel API for Firebase Social & Apple Login
# Successfully processed job 3. Output saved to: output/output_gpt-4_3.txt
# Agent decided not to take job 4: Improve speed loading time and Core Web Vitals
# Agent decided to take job 5: Webflow site build
# Successfully processed job 5. Output saved to: output/output_gpt-4_5.txt
# Agent decided to take job 6: Data entry | Download files and compress a file
# Successfully processed job 6. Output saved to: output/output_gpt-4_6.txt
# Agent decided not to take job 7: Configure pppoe client via pppd and site to site layer 2 openvpn all via terminal
# Agent decided to take job 8: Add custom domain in form & webhook settings in self-hosted n8n
# Successfully processed job 8. Output saved to: output/output_gpt-4_8.txt
# Agent decided not to take job 9: Chrome/Gmail plugin or Extension for File Sharing application
# Agent decided to take job 10: Designing a  wiring part on detected symbols of electrical diagrams.
# Successfully processed job 10. Output saved to: output/output_gpt-4_10.txt
# Agent decided not to take job 11: Create AI generated video
# Agent decided to take job 12: Telegram Bot to post new token creation alerts and liquidity pool additions on Eth and BNB
# Successfully processed job 12. Output saved to: output/output_gpt-4_12.txt
# Agent decided not to take job 13: Deploy my Wordpress to Elastic Beanstalk on AWS
# Agent decided to take job 14: ChatGPT Machine Learning AI Prompt Creation
# Successfully processed job 14. Output saved to: output/output_gpt-4_14.txt
# Agent decided to take job 15: Simple android app share file
# Successfully processed job 15. Output saved to: output/output_gpt-4_15.txt
# Agent decided to take job 16: looking for a logo for my youtube channel and I want a short intro video for the channel
# Successfully processed job 16. Output saved to: output/output_gpt-4_16.txt
# Agent decided not to take job 17: Develop shopify app
# Agent decided not to take job 18: Python Flask app for appointments
# Agent decided not to take job 19: Need a designer to update 30 marketing pieces with new logo, colors, and info."
# Agent decided not to take job 20: Outreach list for niche research
# Agent decided not to take job 21: Need Editing and Proofreading - 4500 words
# Agent decided to take job 22: Accountant bookkeeper
# Successfully processed job 22. Output saved to: output/output_gpt-4_22.txt
# Agent decided not to take job 23: Edit videos
# Agent decided to take job 24: Mr.
# Successfully processed job 24. Output saved to: output/output_gpt-4_24.txt
# Agent decided to take job 25: Podcast cover art, branding, editing
# Successfully processed job 25. Output saved to: output/output_gpt-4_25.txt
# Agent decided to take job 26: Simple web page scrape
# Successfully processed job 26. Output saved to: output/output_gpt-4_26.txt
# Agent decided to take job 27: Need to use Amazon or Keepa API to pull lowest used price into a google sheet based on the ASIN
# Successfully processed job 27. Output saved to: output/output_gpt-4_27.txt
# Agent decided not to take job 28: Need e-commerce website with multiple account creation, functionality, and payment processing
# Agent decided to take job 29: Excel Workbook
# Successfully processed job 29. Output saved to: output/output_gpt-4_29.txt
# Agent decided not to take job 30: Transcribe (Simplified Chinese) and Translate to English
# Agent decided not to take job 31: Premiere Pro - Aligning Progression Drone Visits
# Agent decided to take job 32: APA Reference Formatting for Self-Help Book
# Successfully processed job 32. Output saved to: output/output_gpt-4_32.txt
# Agent decided not to take job 33: Replace 5 PNG file in PSD mockup
# Agent decided to take job 34: Update the wording in one graphic picture.
# Successfully processed job 34. Output saved to: output/output_gpt-4_34.txt
# Agent decided to take job 35: Basic Mobile App for Takeaway Restaurant Business
# Successfully processed job 35. Output saved to: output/output_gpt-4_35.txt
# Agent decided not to take job 36: Mighty Networks Setup Needed
# Agent decided to take job 37: Facebook and TikTok Video editing
# Successfully processed job 37. Output saved to: output/output_gpt-4_37.txt
# Agent decided to take job 38: Embroidery Digitizing
# Successfully processed job 38. Output saved to: output/output_gpt-4_38.txt
# Agent decided to take job 39: 3D logo intro video ( 10-15 second )
# Successfully processed job 39. Output saved to: output/output_gpt-4_39.txt
# Agent decided to take job 40: Django Developer Needed for Website with PostgreSQL & MinIO Integration
# Successfully processed job 40. Output saved to: output/output_gpt-4_40.txt
# Agent decided not to take job 41: Build Landing Page and Prototype/Wireframe for Web Portal.
# Agent decided to take job 42: Video Edit
# Successfully processed job 42. Output saved to: output/output_gpt-4_42.txt
# Agent decided not to take job 43: Research competitors best selling products
# Agent decided to take job 44: Build responsive landing page on wix
# Successfully processed job 44. Output saved to: output/output_gpt-4_44.txt
# Agent decided to take job 45: InDesign Book Layout Specialist
# Successfully processed job 45. Output saved to: output/output_gpt-4_45.txt
# Agent decided to take job 46: Unity Web Based Code Retrieval
# Successfully processed job 46. Output saved to: output/output_gpt-4_46.txt
# Agent decided not to take job 47: Facebook Banner Design for Beauty Therapist
# Agent decided to take job 48: RTSP and WebRTC bug fix
# Successfully processed job 48. Output saved to: output/output_gpt-4_48.txt
# Agent decided not to take job 49: Logo Design
# Agent decided to take job 50: Notion expert to create a template planner for our team.
# Successfully processed job 50. Output saved to: output/output_gpt-4_50.txt
# Agent decided not to take job 51: Stripe set up
# Agent decided to take job 52: Fashion prints needed for upcoming label
# Successfully processed job 52. Output saved to: output/output_gpt-4_52.txt
# Agent decided not to take job 53: Animated infographic / Designer needed
# Agent decided not to take job 54: Tech pack for boxers/ men’s underwear
# Agent decided not to take job 55: Synfig Studio animation (15s) needed
# Agent decided not to take job 56: Need python script to automatically remove silence from audios mp3
# Agent decided not to take job 57: Xiao ESP32C AT command programming
# Agent decided to take job 58: Create 7 self-directed courses on my website
# Successfully processed job 58. Output saved to: output/output_gpt-4_58.txt
# Agent decided not to take job 59: Custom Template  1 page sitr Creation
# Agent decided not to take job 60: French translation for toy packaging and internal user manual
# Agent decided not to take job 61: I need to write documents and casses for VR game development.
# Agent decided not to take job 62: Powerpoint and Charts
# Agent decided not to take job 63: Converting a business directory to publish on kdp
# Agent decided not to take job 64: Design inside pages of a TEXTbook/workbook for Amazon KDP
# Agent decided not to take job 65: 3d File for Website Landing Page
# Agent decided not to take job 66: Create 3D Rendering Product Photo of a Bag
# Agent decided not to take job 67: Sqaurespace website developer
# Agent decided to take job 68: Website
# Successfully processed job 68. Output saved to: output/output_gpt-4_68.txt
# Agent decided not to take job 69: Internet researcher Today:  Help me find .pdfs of customer case studies from B2B software companies?
# Agent decided not to take job 70: Mobile app to find people who helps practice languages
# Agent decided to take job 71: Build mini website for google reviews
# Successfully processed job 71. Output saved to: output/output_gpt-4_71.txt
# Agent decided to take job 72: Need a custom rendering of a mold for soap/lotion
# Successfully processed job 72. Output saved to: output/output_gpt-4_72.txt
# Agent decided to take job 73: I need someone who is an animator
# Successfully processed job 73. Output saved to: output/output_gpt-4_73.txt
# Agent decided not to take job 74: List Building: Targeted Marketing Contact List Research & Compilation
# Agent decided not to take job 75: Google Calendar for Shift Sign Up
# Agent decided not to take job 76: Logo design for local guide
# Agent decided to take job 77: Data Pooling Expert
# Successfully processed job 77. Output saved to: output/output_gpt-4_77.txt
# Agent decided not to take job 78: Need a restaurant menu edited
# Agent decided to take job 79: Graphical Abstract Design for MXene-based Meta-Absorber
# Successfully processed job 79. Output saved to: output/output_gpt-4_79.txt
# Agent decided to take job 80: Improve Image
# Successfully processed job 80. Output saved to: output/output_gpt-4_80.txt
# Agent decided not to take job 81: Wordpress migration and elementor issues
# Agent decided to take job 82: Modification in dating app
# Successfully processed job 82. Output saved to: output/output_gpt-4_82.txt
# Agent decided not to take job 83: Wordpress Plugin Developer
# Agent decided to take job 84: One week Job - Code Simple Landing page
# Successfully processed job 84. Output saved to: output/output_gpt-4_84.txt
# Agent decided not to take job 85: Squarespace technical website help
# Agent decided to take job 86: PCB Board Desgin
# Successfully processed job 86. Output saved to: output/output_gpt-4_86.txt
# Agent decided to take job 87: Build a responsive  wordpress website
# Successfully processed job 87. Output saved to: output/output_gpt-4_87.txt
# Agent decided not to take job 88: Editing job
# Agent decided not to take job 89: Amazon listing graphics and A+ content design
# Agent decided not to take job 90: Create animation for video intro
# Agent decided to take job 91: Pdf form field editor
# Successfully processed job 91. Output saved to: output/output_gpt-4_91.txt
# Agent decided not to take job 92: T-shirt and cap design
# Agent decided not to take job 93: Ethereum Gas Testing Proof-of-Concept
# Agent decided not to take job 94: Amazon images and video
# Agent decided to take job 95: Edit YOUTUBE Thumbnails
# Successfully processed job 95. Output saved to: output/output_gpt-4_95.txt
# Agent decided to take job 96: Data Entry - Look up home prices on Zillow - FOR ASQA K.
# Successfully processed job 96. Output saved to: output/output_gpt-4_96.txt
# Agent decided not to take job 97: Need google sheet that updates when new data is added
# Agent decided not to take job 98: Website
# Agent decided to take job 99: General Typing of Documents
# Successfully processed job 99. Output saved to: output/output_gpt-4_99.txt
# Agent decided to take job 100: Need video - voiceover explainer video
# Successfully processed job 100. Output saved to: output/output_gpt-4_100.txt
# Agent decided not to take job 101: Smart Contract Deployment
# Agent decided to take job 102: Data Extraction
# Successfully processed job 102. Output saved to: output/output_gpt-4_102.txt
# Agent decided not to take job 103: Typist
# Agent decided not to take job 104: List Building
# Agent decided to take job 105: Re-create this poster in hi res print format
# Successfully processed job 105. Output saved to: output/output_gpt-4_105.txt
# Agent decided to take job 106: Build 3d Renderings and Plans of Repurposed City Buses
# Successfully processed job 106. Output saved to: output/output_gpt-4_106.txt
# Agent decided not to take job 107: Dokan Modifications
# Agent decided not to take job 108: Populate Excel Using API
# Agent decided not to take job 109: Wordpress Guru Needed
# Agent decided to take job 110: Data Entry- Provide entry from a restaurant menu into another
# Successfully processed job 110. Output saved to: output/output_gpt-4_110.txt
# Agent decided to take job 111:  developer to create a receipt generation system
# Successfully processed job 111. Output saved to: output/output_gpt-4_111.txt
# Agent decided not to take job 112: Food products Website
# Agent decided not to take job 113: Financial Services organizations
# Agent decided to take job 114: Lead generation
#
# Successfully processed job 114. Output saved to: output/output_gpt-4_114.txt
# Agent decided not to take job 115: Need Expert Compositor to Mask Transition 2 Clips Seamlessly
# Agent decided not to take job 116: Change quantity selection from dropdown to button
# Agent decided to take job 117: Deep Learning Model Training and Deployment on Nvidia Jetson Devices
# Successfully processed job 117. Output saved to: output/output_gpt-4_117.txt
# Agent decided to take job 118: Create a post mailing list
# Successfully processed job 118. Output saved to: output/output_gpt-4_118.txt
# Agent decided to take job 119: Create Bottle Labels
# Successfully processed job 119. Output saved to: output/output_gpt-4_119.txt
# Agent decided to take job 120: Create direct mailing list for property owners
# Successfully processed job 120. Output saved to: output/output_gpt-4_120.txt
# Agent decided to take job 121: Bzr site work
# Successfully processed job 121. Output saved to: output/output_gpt-4_121.txt
# Agent decided not to take job 122: Logo for PALESTINE
# Agent decided to take job 123: Structural Engineer Needed to Review a Hanging Metal Retail Canopy
# Successfully processed job 123. Output saved to: output/output_gpt-4_123.txt
# Agent decided to take job 124: Autocad Design Electrical Engineering
# Successfully processed job 124. Output saved to: output/output_gpt-4_124.txt
# Agent decided not to take job 125: Need Wordpress Page Converted to HTML
# Agent decided to take job 126: HTML + TailwindCSS for 5 page website (fully responsive)
# Successfully processed job 126. Output saved to: output/output_gpt-4_126.txt
# Agent decided to take job 127: Design a Logo
# Successfully processed job 127. Output saved to: output/output_gpt-4_127.txt
# Agent decided not to take job 128: Lead Scraper Needed for Business Contacts
# Agent decided not to take job 129: Graphic design
# Agent decided to take job 130: Documents Retyping
# Successfully processed job 130. Output saved to: output/output_gpt-4_130.txt
# Agent decided not to take job 131: Test Project - Ongoing Tableau Dashboard Development Work
# Agent decided not to take job 132: Soa school project
# Agent decided to take job 133: Edit previous project
# Successfully processed job 133. Output saved to: output/output_gpt-4_133.txt
# Agent decided not to take job 134: Experienced Python Developer And Web Scraper
# Agent decided to take job 135: TikTok video editor
# Successfully processed job 135. Output saved to: output/output_gpt-4_135.txt
# Agent decided to take job 136: I need help with animation and a mascot creation for my brand. Emailemu.com
# Successfully processed job 136. Output saved to: output/output_gpt-4_136.txt
# Agent decided not to take job 137: SaaS landing page web design
# Agent decided not to take job 138: Python combinations / unique combos from lists
# Agent decided not to take job 139: Portfolio website backend
# Agent decided not to take job 140: Logo Design
# Agent decided not to take job 141: Data Research - real estate
# Agent decided not to take job 142: Grant Writer/Researcher needed for fast turnaround Grant Prospectus
# Agent decided not to take job 143: PDF to Excel Formatting
# Agent decided to take job 144: Finish a google sketchup drawing for me
# Successfully processed job 144. Output saved to: output/output_gpt-4_144.txt
# Agent decided not to take job 145: Chorme extension based on openai vision api
# Agent decided not to take job 146: Need a gif created for Happy New Year 2024
# Agent decided to take job 147: Reformat a Children's Book
# Successfully processed job 147. Output saved to: output/output_gpt-4_147.txt
# Agent decided to take job 148: Add a custom pop-up to Gravity form in WordPress site
# Successfully processed job 148. Output saved to: output/output_gpt-4_148.txt
# Agent decided not to take job 149: Making Llama (LLM) Labeling Model work
# Agent decided not to take job 150: Website updates
# Agent decided to take job 151: Create and Design a Landing page - Real Estate Activities
# Successfully processed job 151. Output saved to: output/output_gpt-4_151.txt
# Agent decided to take job 152: Course Content Pro needed.
# Successfully processed job 152. Output saved to: output/output_gpt-4_152.txt
# Agent decided not to take job 153: Shopify store expert needed
# Agent decided to take job 154: Fix minor Issues and Burger Menu for Webflow Website
# Successfully processed job 154. Output saved to: output/output_gpt-4_154.txt
# Agent decided to take job 155: Mobile Application for ELM327 OBD Dongle
# Successfully processed job 155. Output saved to: output/output_gpt-4_155.txt
# Agent decided not to take job 156: Add products, descriptions and upload images for a WordPress web shop
# Agent decided to take job 157: Exterior Rendering Video - Lumion
# Successfully processed job 157. Output saved to: output/output_gpt-4_157.txt
# Agent decided to take job 158: Create List of Positive Impact Conferences Gloibally
# Successfully processed job 158. Output saved to: output/output_gpt-4_158.txt
# Agent decided to take job 159: UI/UX solution for 3 features of our Mobile App
# Successfully processed job 159. Output saved to: output/output_gpt-4_159.txt
# Agent decided to take job 160: UI/UX development for my web design
# Successfully processed job 160. Output saved to: output/output_gpt-4_160.txt
# Agent decided to take job 161: Graphic Designer Needed to Highlight Exclusive 'Guest Card' Feature in Airbnb Listing
# Successfully processed job 161. Output saved to: output/output_gpt-4_161.txt
# Agent decided to take job 162: Godot iOS Plugin
# Successfully processed job 162. Output saved to: output/output_gpt-4_162.txt
# Agent decided to take job 163: Video Editor and Animator
# Successfully processed job 163. Output saved to: output/output_gpt-4_163.txt
# Agent decided to take job 164: Transcription of Interviews to Prevent Diabetes in Latino Families
# Successfully processed job 164. Output saved to: output/output_gpt-4_164.txt
# Agent decided to take job 165: Jotform Design
# Successfully processed job 165. Output saved to: output/output_gpt-4_165.txt
# Agent decided to take job 166: Translation of technical text, English - French
# Successfully processed job 166. Output saved to: output/output_gpt-4_166.txt
# Agent decided to take job 167: Laravel Backend Developer - Connecting several  API-Endpoints
# Successfully processed job 167. Output saved to: output/output_gpt-4_167.txt
# Agent decided to take job 168: Formatting ebooks
# Successfully processed job 168. Output saved to: output/output_gpt-4_168.txt
# Agent decided not to take job 169: Install Ai Chatbot into Squarespace website
# Agent decided not to take job 170: Figma to Angular - UI/UX Screen Development
# Agent decided to take job 171: 3CX LightSail Upgrade
# Successfully processed job 171. Output saved to: output/output_gpt-4_171.txt
# Agent decided to take job 172: Square Space - adding
# Successfully processed job 172. Output saved to: output/output_gpt-4_172.txt
# Agent decided to take job 173: Flutter chat video audio calls use WebRtc with linux host and Laravel backend
# Successfully processed job 173. Output saved to: output/output_gpt-4_173.txt
# Agent decided not to take job 174: Develop Market Research of Sustainable Clothing Brands
# Agent decided to take job 175: Parse 238 websites and get data
# Successfully processed job 175. Output saved to: output/output_gpt-4_175.txt
# Agent decided to take job 176: Graphic Designer for Baking Business
# Successfully processed job 176. Output saved to: output/output_gpt-4_176.txt
# Agent decided to take job 177: Logo for photography business
# Successfully processed job 177. Output saved to: output/output_gpt-4_177.txt
# Agent decided to take job 178: Create simple Android App to practice multiplication
# Successfully processed job 178. Output saved to: output/output_gpt-4_178.txt
# Agent decided to take job 179: English to Romanian Translation
# Successfully processed job 179. Output saved to: output/output_gpt-4_179.txt
# Agent decided not to take job 180: I want to edit a vlog video for my YouTube channel.
# Agent decided not to take job 181: Copy typing
# Agent decided not to take job 182: Saloons Company in USA
# Agent decided to take job 183: Build a Shopify app that can create ads in a new space
# Successfully processed job 183. Output saved to: output/output_gpt-4_183.txt
# Agent decided not to take job 184: Integrate TipTap (rich text editor) into an Open Source document data processor based on Tauri
# Agent decided not to take job 185: Edit 4-12 GB sized TV episodes for YouTube upload
# Agent decided to take job 186: Translate bookkeeping audit from spanish to english
# Successfully processed job 186. Output saved to: output/output_gpt-4_186.txt
# Agent decided to take job 187: Build a website
# Successfully processed job 187. Output saved to: output/output_gpt-4_187.txt

# %% [markdown]
# # Grading Submitted Results
#
# We will now take all of the outputs and verify them.  We do this doing a very simple wrapper around an LLM that takes a look at all the output files and determines whether the output deserved to earn payment or not.  However, this can be done in several other ways:
# - By human verification (using freelancers who are experts in this area)
# - By using a well-trained LLM (i.e. Uma trained on this task)
# - By the client themselves.

# %%
from dotenv import load_dotenv
import os
load_dotenv()  # take environment variables

from agent.verifier_simple import SimpleVerifier
from api.data import AgentArenaData

csv_data = "data/df_randomized_feasible_cleaned.csv"

# Initialize the data
data = AgentArenaData(csv_data)

# Verifying the Output
verifier = SimpleVerifier(os.getenv("OPENAI_API_KEY"), data)
verifier.process_outputs("output/")
# Out:
# Job: Re-create this poster in hi res print format (ID: 105)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job:  developer to create a receipt generation system (ID: 111)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Data Entry- Provide entry from a restaurant menu into another (ID: 110)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Telegram Bot to post new token creation alerts and liquidity pool additions on Eth and BNB (ID: 12)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Designing a  wiring part on detected symbols of electrical diagrams. (ID: 10)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Embroidery Digitizing  (ID: 38)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Build 3d Renderings and Plans of Repurposed City Buses (ID: 106)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: 3D logo intro video ( 10-15 second ) (ID: 39)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Excel Workbook (ID: 29)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Simple android app share file (ID: 15)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Deep Learning Model Training and Deployment on Nvidia Jetson Devices  (ID: 117)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Data Extraction  (ID: 102)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: ChatGPT Machine Learning AI Prompt Creation (ID: 14)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: looking for a logo for my youtube channel and I want a short intro video for the channel (ID: 16)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Need video - voiceover explainer video (ID: 100)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Lead generation
#  (ID: 114)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Create 7 self-directed courses on my website (ID: 58)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Translation of technical text, English - French (ID: 166)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Square Space - adding  (ID: 172)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Flutter chat video audio calls use WebRtc with linux host and Laravel backend (ID: 173)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Laravel Backend Developer - Connecting several  API-Endpoints (ID: 167)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Build mini website for google reviews  (ID: 71)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: I need someone who is an animator (ID: 73)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: 3CX LightSail Upgrade (ID: 171)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Jotform Design (ID: 165)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: UI/UX solution for 3 features of our Mobile App (ID: 159)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Create List of Positive Impact Conferences Gloibally (ID: 158)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Transcription of Interviews to Prevent Diabetes in Latino Families (ID: 164)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: General Typing of Documents (ID: 99)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Need a custom rendering of a mold for soap/lotion (ID: 72)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Add a custom pop-up to Gravity form in WordPress site (ID: 148)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: UI/UX development for my web design (ID: 160)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Graphic Designer Needed to Highlight Exclusive 'Guest Card' Feature in Airbnb Listing (ID: 161)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Parse 238 websites and get data (ID: 175)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Add custom domain in form & webhook settings in self-hosted n8n (ID: 8)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Data Pooling Expert (ID: 77)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Video Editor and Animator (ID: 163)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Logo for photography business (ID: 177)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Graphic Designer for Baking Business (ID: 176)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Godot iOS Plugin (ID: 162)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: RTSP and WebRTC bug fix (ID: 48)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: InDesign Book Layout Specialist (ID: 45)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Graphical Abstract Design for MXene-based Meta-Absorber (ID: 79)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: PCB Board Desgin (ID: 86)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Reformat a Children's Book (ID: 147)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Data entry | Download files and compress a file (ID: 6)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Course Content Pro needed.  (ID: 152)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Build a responsive  wordpress website  (ID: 87)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Build responsive landing page on wix (ID: 44)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Notion expert to create a template planner for our team. (ID: 50)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Unity Web Based Code Retrieval  (ID: 46)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Fashion prints needed for upcoming label (ID: 52)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Pdf form field editor (ID: 91)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Build a website (ID: 187)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Webflow site build (ID: 5)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Finish a google sketchup drawing for me  (ID: 144)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Create simple Android App to practice multiplication (ID: 178)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: English to Romanian Translation (ID: 179)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Create and Design a Landing page - Real Estate Activities (ID: 151)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Translate bookkeeping audit from spanish to english (ID: 186)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: One week Job - Code Simple Landing page (ID: 84)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Improve Image (ID: 80)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Mobile Application for ELM327 OBD Dongle (ID: 155)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Fix minor Issues and Burger Menu for Webflow Website (ID: 154)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Formatting ebooks (ID: 168)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Build a Shopify app that can create ads in a new space (ID: 183)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Edit YOUTUBE Thumbnails (ID: 95)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Video Edit (ID: 42)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Website (ID: 68)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Django Developer Needed for Website with PostgreSQL & MinIO Integration (ID: 40)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Fix Laravel API for Firebase Social & Apple Login (ID: 3)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Exterior Rendering Video - Lumion (ID: 157)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Italian typist (ID: 2)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Modification in dating app (ID: 82)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Data Entry - Look up home prices on Zillow - FOR ASQA K. (ID: 96)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: APA Reference Formatting for Self-Help Book (ID: 32)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Simple web page scrape (ID: 26)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Autocad Design Electrical Engineering (ID: 124)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Documents Retyping (ID: 130)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Create a post mailing list (ID: 118)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Create Bottle Labels (ID: 119)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Need to use Amazon or Keepa API to pull lowest used price into a google sheet based on the ASIN (ID: 27)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Podcast cover art, branding, editing (ID: 25)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Edit previous project (ID: 133)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Design a Logo (ID: 127)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: HTML + TailwindCSS for 5 page website (fully responsive) (ID: 126)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Mr. (ID: 24)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Update the wording in one graphic picture. (ID: 34)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: I need help with animation and a mascot creation for my brand. Emailemu.com   (ID: 136)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Structural Engineer Needed to Review a Hanging Metal Retail Canopy (ID: 123)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Basic Mobile App for Takeaway Restaurant Business (ID: 35)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Facebook and TikTok Video editing (ID: 37)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Job: Bzr site work (ID: 121)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: TikTok video editor (ID: 135)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Create direct mailing list for property owners (ID: 120)
# Agent: gpt-4
# Result: ✗ FAILURE
# --------------------------------------------------------------------------------
#
# Job: Accountant bookkeeper (ID: 22)
# Agent: gpt-4
# Result: ✓ SUCCESS
# --------------------------------------------------------------------------------
#
# Results saved to output/results.csv

# %%
import pandas as pd

csv_results = "output/results.csv"

df = pd.read_csv(csv_results)
df.head()
# Out:
#    Unnamed: 0 gpt-4
# 0           2  fail
# 1           3   win
# 2           5  fail
# 3           6  fail
# 4           8   win
